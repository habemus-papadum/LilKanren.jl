# %%
include("../../src/v1/LilKanren.jl")
using LilKanren

# %%
## basics
slurp() do q, a, b, c, d, e
    ( q     ≡ (:♣, :♠) )  ∧
    ( (a,b) ≡ q        )  ∧
    ( c     ≡ (1,d)    )  ∧
    ( d     ≡ (1,c)    )
end
# Out:
# <div style="font-family:Monaco"><div style="font-family:Monaco"><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-family:Monaco"><span style="font-family:Monaco">(</span><span style="font-family:Monaco">♣</span><span style="font-family:Monaco">, </span><span style="font-family:Monaco">♠</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">a</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-family:Monaco">♣</span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">b</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-family:Monaco">♠</span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">c</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-family:Monaco"><span style="font-family:Monaco">(</span><span style="font-family:Monaco">1</span><span style="font-family:Monaco">, </span><span style="font-family:Monaco"><span style="font-family:Monaco">(</span><span style="font-family:Monaco">1</span><span style="font-family:Monaco">, </span><span style="font-family:Monaco;font-style:italic">c</span><span style="font-family:Monaco">)</span></span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">d</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-family:Monaco"><span style="font-family:Monaco">(</span><span style="font-family:Monaco">1</span><span style="font-family:Monaco">, </span><span style="font-family:Monaco;font-style:italic">c</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">e</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-family:Monaco;font-style:italic"><span style="font-family:Monaco">✽</span><sub>1</sub></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 6, Steps: 1, Time: 2.67 ms</span></div></div></div></div><div style="font-family:Monaco"><pre>Summary:
# ==============================
# Total # of steps: 1
# Total # of results: 1  (100.00% Hit rate)
# Total Time: 2.69 ms 2.69 ms/step 2.69 ms/result
# Total GC Time: 0.000000 ηs 0.00 ηs/step 0.00 ηs/result (0.00%)
# Total GC Bytes: 9.23 KB 9.23 KB/step 9.23 KB/result
# </pre></div></div>

# %%
## The "Classic"
#############################
function appendᵒ(o,front,back)
  ∨(    # <-- Applicative form of Disjunction
    # The base case
    ∧(() ≡ front,
       o ≡ back),

    # The recursive case
    fresh(3) do h,t,temp
      ∧((h,t)    ≡ front,
        (h,temp) ≡ o,
        @☾(appendᵒ(temp,t,back)))
    end)
end
# Out:
# appendᵒ (generic function with 1 method)

# %%
## run it forwards
slurp() do q
    appendᵒ(q,
            ❀(:✌︎, :✒︎, :✂︎, :☼),
            ❀(:☿,:♆))
end
# Out:
# <div style="font-family:Monaco"><div style="font-family:Monaco"><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✌︎</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✒︎</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✂︎</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">☼</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">☿</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">♆</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 13, Steps: 5, Time: 18.46 ms</span></div></div></div></div><div style="font-family:Monaco"><pre>Summary:
# ==============================
# Total # of steps: 5
# Total # of results: 1  (20.00% Hit rate)
# Total Time: 18.48 ms 3.70 ms/step 18.48 ms/result
# Total GC Time: 0.000000 ηs 0.00 ηs/step 0.00 ηs/result (0.00%)
# Total GC Bytes: 89.67 KB 17.93 KB/step 89.67 KB/result
# </pre></div></div>

# %%
## run it backwards
slurp() do front, back
    appendᵒ(❀(:✌︎, :✒︎, :✂︎, :☼,:☿),
            front,
            back)
end
# Out:
# <div style="font-family:Monaco"><div style="font-family:Monaco"><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">front</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-family:Monaco">❀()</span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">back</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✌︎</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✒︎</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✂︎</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">☼</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">☿</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 2, Steps: 1, Time: 7.48 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">front</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✌︎</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">back</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✒︎</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✂︎</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">☼</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">☿</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 5, Steps: 1, Time: 7.49 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">front</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✌︎</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✒︎</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">back</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✂︎</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">☼</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">☿</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 8, Steps: 1, Time: 2.35 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">front</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✌︎</span><span style="font-family:Monaco">,</span><span  ...
# ==============================
# Total # of steps: 6
# Total # of results: 6  (100.00% Hit rate)
# Total Time: 17.56 ms 2.93 ms/step 2.93 ms/result
# Total GC Time: 0.000000 ηs 0.00 ηs/step 0.00 ηs/result (0.00%)
# Total GC Bytes: 120.67 KB 20.11 KB/step 20.11 KB/result
# </pre></div></div>

# %%
## "Grammars"
## operators
litᵒ(val) = (x) -> x ≡ ❀(val)

∥(a,b) = (x) -> a(x) ∨ b(x)

→(a,b) = (x) -> begin
  fresh(2) do front,back
    a(front) ∧
    b(back)  ∧
    appendᵒ(x,front,back)
  end
end

## internals
g☾(pred) = (val) -> @☾ pred(val)
pred⁻¹(pred) = :(v -> st -> g☾($(esc(pred)))(v)(st))
macro g☾(pred)
  pred⁻¹(pred)
end
Base.in(val, relation::Function) = relation(val)


## Booleans
trueᵒ = litᵒ(:✓)
falseᵒ = litᵒ(:✗)
𝔹ᵒ =  trueᵒ ∥ falseᵒ 
notᵒ(o,x) = begin
  trueᵒ(x)  ∧ falseᵒ(o) ∨
  falseᵒ(x) ∧ trueᵒ(o)
end

## A random sequence
αβγᵒ = litᵒ(:α) → litᵒ(:β) → litᵒ(:γ)


slurp() do q,r,s
  (q ∈ 𝔹ᵒ)     ∧
  (r ∈ 𝔹ᵒ)     ∧
  (s ∈ αβγᵒ)
end
# Out:
# <div style="font-family:Monaco"><div style="font-family:Monaco"><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✓</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">r</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✓</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">s</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">α</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">β</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">γ</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 13, Steps: 5, Time: 13.06 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✓</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">r</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✗</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">s</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">α</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">β</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">γ</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 13, Steps: 2, Time: 308.57 μs</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✗</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">r</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✓</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">s</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">α</ ...
# ==============================
# Total # of steps: 9
# Total # of results: 4  (44.44% Hit rate)
# Total Time: 13.63 ms 1.51 ms/step 3.41 ms/result
# Total GC Time: 0.000000 ηs 0.00 ηs/step 0.00 ηs/result (0.00%)
# Total GC Bytes: 141.39 KB 15.71 KB/step 35.35 KB/result
# </pre></div></div>

# %%
## Peano numbers
natᵒ = litᵒ(:№𝟘) ∥ (litᵒ(:✚𝟙) → @g☾(natᵒ))

slurp() do q
  q ∈ natᵒ
end
# Out:
# <div style="font-family:Monaco"><div style="font-family:Monaco"><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 1, Steps: 1, Time: 4.22 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 6, Steps: 3, Time: 247.28 μs</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 11, Steps: 4, Time: 243.08 μs</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 16, Steps: 5, Time: 416.09 μs</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 21, Steps: 6, Time: 426.09 μs</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="fon ...
# ==============================
# Total # of steps: 64
# Total # of results: 10  (15.63% Hit rate)
# Total Time: 9.78 ms 152.84 μs/step 978.21 μs/result
# Total GC Time: 0.000000 ηs 0.00 ηs/step 0.00 ηs/result (0.00%)
# Total GC Bytes: 976.17 KB 15.25 KB/step 97.62 KB/result
# </pre></div></div>

# %%
## big endian binary
№𝟘ᵒ = litᵒ(:№𝟘)
№𝟙ᵒ  = litᵒ(:№𝟙)

binaryᵒ = №𝟘ᵒ ∥ @g☾(posᵒ)
posᵒ    = №𝟙ᵒ ∥ @g☾(gt𝟙ᵒ)
gt𝟙ᵒ    = @g☾(posᵒ) → (№𝟘ᵒ ∥ №𝟙ᵒ)


slurp() do q
  q ∈ binaryᵒ
end
# Out:
# <div style="font-family:Monaco"><div style="font-family:Monaco"><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 1, Steps: 1, Time: 4.06 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">№𝟙</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 1, Steps: 1, Time: 2.86 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">№𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 6, Steps: 4, Time: 3.37 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">№𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟙</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 6, Steps: 1, Time: 21.59 μs</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">№𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 14, Steps: 7, Time: 607.66 μs</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">№𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟙</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt; ...
# ==============================
# Total # of steps: 35
# Total # of results: 10  (28.57% Hit rate)
# Total Time: 12.71 ms 363.16 μs/step 1.27 ms/result
# Total GC Time: 0.000000 ηs 0.00 ηs/step 0.00 ηs/result (0.00%)
# Total GC Bytes: 348.69 KB 9.96 KB/step 34.87 KB/result
# </pre></div></div>

# %%
## catamorphisms
function peanoᵒkitty(z,s)
  r = (o,v) -> begin
    ((v ≡ ❀(:№𝟘)) ∧ z(o)) ∨
    fresh(2) do n,o′
      (v ≡ (:✚𝟙, n)) ∧
      s(o,o′)        ∧
      @☾ r(o′,n)     
    end
  end
end

#############################


evenᵒ = peanoᵒkitty( o ->  trueᵒ(o),
                     (o,o′) -> notᵒ(o,o′))

slurp() do q
  fresh() do parity
    (q ∈ natᵒ)         ∧
    evenᵒ(parity, q)   ∧
    trueᵒ(parity)     
  end
end
# Out:
# <div style="font-family:Monaco"><div style="font-family:Monaco"><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 2, Steps: 1, Time: 13.95 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 16, Steps: 17, Time: 5.27 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 30, Steps: 29, Time: 3.36 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 44, Steps: 41, Time: 4.69 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">q</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family ...
# ==============================
# Total # of steps: 586
# Total # of results: 10  (1.71% Hit rate)
# Total Time: 138.02 ms 235.53 μs/step 13.80 ms/result
# Total GC Time: 24.55 ms 41.89 μs/step 2.46 ms/result (17.79%)
# Total GC Bytes: 20.24 MB 35.37 KB/step 2.02 MB/result
# </pre></div></div>

# %%
#############################
plusᵒ(o,x,y) = begin
  plusxᵒ = peanoᵒkitty(o ->  o ≡ x,
                       (o,o′) -> o ≡ (:✚𝟙,o′))
  plusxᵒ(o,y)
end


# Partition 5
slurp() do x,y
  plusᵒ(❀(:✚𝟙, :✚𝟙, :✚𝟙, :✚𝟙, :✚𝟙, :№𝟘), x, y)
end
# Out:
# <div style="font-family:Monaco"><div style="font-family:Monaco"><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">x</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">y</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 2, Steps: 1, Time: 5.07 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">x</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">y</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 4, Steps: 1, Time: 90.26 μs</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">x</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">y</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;fon ...
# ==============================
# Total # of steps: 6
# Total # of results: 6  (100.00% Hit rate)
# Total Time: 5.49 ms 914.77 μs/step 914.77 μs/result
# Total GC Time: 0.000000 ηs 0.00 ηs/step 0.00 ηs/result (0.00%)
# Total GC Bytes: 65.72 KB 10.95 KB/step 10.95 KB/result
# </pre></div></div>

# %%
#############################
multᵒ(o,x,y) = begin
  multxᵒ = peanoᵒkitty(o ->  o ≡ ❀(:№𝟘),
                       (o,o′) -> plusᵒ(o,o′,x) )
  multxᵒ(o,y)
end

## Factor 6
slurp() do x,y
  multᵒ(❀(:✚𝟙, :✚𝟙, :✚𝟙, :✚𝟙, :✚𝟙, :✚𝟙, :№𝟘), x, y)
end

## diverges, but finds all answers
# Out:
# <div style="font-family:Monaco"><div style="font-family:Monaco"><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">x</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">y</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 26, Steps: 48, Time: 13.28 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">x</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">y</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 20, Steps: 8, Time: 885.66 μs</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">x</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">№𝟘</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">y</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">✚𝟙</span><span style="font-family:Monaco">,</span><span style="font-family:Monaco">✚𝟙</span><span style="f ...
# ==============================
# Total # of steps: 1850
# Total # of results: 4  (0.22% Hit rate)
# Total Time: 5.00 s 2.70 ms/step 1.25 s/result
# Total GC Time: 846.02 ms 457.31 μs/step 211.50 ms/result (16.92%)
# Total GC Bytes: 1.48 GB 840.44 KB/step 379.59 MB/result
# </pre></div></div>

# %%
######################### 
## Smullyan Puzzles !!!

# You journey upon an island which has two types of inhabitants:
#   Knights, who always tell the truth 
#   and Knaves, who always lie.
# 
#  During your travels, you encounter two inhabitants, Will and Dan.
#  Will says, "Dan will say that I'm a Knight"
#
#  Who's who?
#########################

♞ᵒ = litᵒ(:♞) ## Knights 
⚗ᵒ = litᵒ(:⚗)  ## Knaves

Inhabitantᵒ = ♞ᵒ ∥ ⚗ᵒ 

   
function Inhabitantᵒkitty(♞,⚗)
  r = (o,v) -> begin
    (v ∈ ♞ᵒ) ∧ ♞(o)  ∨
    (v ∈ ⚗ᵒ)  ∧ ⚗(o)
  end
  r
end
 
## binary relation
is♞ᵒ = Inhabitantᵒkitty( o -> trueᵒ(o),
                          o -> falseᵒ(o)) 
shallSayᵒ(o,who,what) = begin
  r = Inhabitantᵒkitty( o -> o ≡ what, 
                        o -> notᵒ(o,what))
  r(o,who)
end

slurp() do Will, Dan
  fresh(2) do Will′s_Statement,Dan′s_Statement
    shallSayᵒ(❀(:✓),Will,Will′s_Statement)              ∧
    shallSayᵒ(Will′s_Statement,Dan,Dan′s_Statement)      ∧
    is♞ᵒ(Dan′s_Statement,Will)
  end
end
# Out:
# <div style="font-family:Monaco"><div style="font-family:Monaco"><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">Will</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">♞</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">Dan</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">♞</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 4, Steps: 1, Time: 21.30 ms</span></div></div></div><div style="font-family:Monaco;margin:10px"><div style="font-family:Monaco"><table class="array"><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">Will</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">⚗</span><span style="font-family:Monaco">)</span></span></span></td></tr><tr><td margin="10px"><span style="font-family:Monaco;margin:10px">Dan</span></td><td margin="10px"><span style="font-family:Monaco;margin:10px"><span style="font-size:smaller;font-family:Monaco"><span style="font-family:Monaco">❀(</span><span style="font-family:Monaco">♞</span><span style="font-family:Monaco">)</span></span></span></td></tr></table><div style="font-size:8pt;font-family:Monaco"><span style="font-family:Monaco">Vars Alloc'd: 4, Steps: 0, Time: 19.50 μs</span></div></div></div></div><div style="font-family:Monaco"><pre>Summary:
# ==============================
# Total # of steps: 1
# Total # of results: 2  (200.00% Hit rate)
# Total Time: 21.33 ms 21.33 ms/step 10.66 ms/result
# Total GC Time: 0.000000 ηs 0.00 ηs/step 0.00 ηs/result (0.00%)
# Total GC Bytes: 84.68 KB 84.68 KB/step 42.34 KB/result
# </pre></div></div>

# %%
# Dan's a ♞, can't be sure about that Will....
